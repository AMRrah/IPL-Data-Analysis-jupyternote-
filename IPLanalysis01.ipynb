# %% [markdown]
# # Ipl Data Analysis 2008-2024

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('deliveries.csv')
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
match=pd.read_csv('matches.csv')
type(match)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
match.head()
# Out:
#        id   season        city       date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  4/18/2008     League     BB McCullum
# 1  335983  2007/08  Chandigarh  4/19/2008     League      MEK Hussey
# 2  335984  2007/08       Delhi  4/19/2008     League     MF Maharoof
# 3  335985  2007/08      Mumbai  4/20/2008     League      MV Boucher
# 4  335986  2007/08     Kolkata  4/20/2008     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
data.head().plot(x='ball',y='total_runs')
# Out:
# <Axes: xlabel='ball'>

# %%
data.head(50).plot(x='ball',y='total_runs')
# Out:
# <Axes: xlabel='ball'>

# %%
data.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
match.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
match.team1.unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
match.team2.unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Royal Challengers Bangalore', 'Deccan Chargers',
#        'Kings XI Punjab', 'Delhi Daredevils', 'Mumbai Indians',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Gujarat Titans', 'Lucknow Super Giants',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
data.batter.unique()
# Out:
# array(['SC Ganguly', 'BB McCullum', 'RT Ponting', 'DJ Hussey',
#        'Mohammad Hafeez', 'R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis',
#        'CL White', 'MV Boucher', 'B Akhil', 'AA Noffke', 'P Kumar',
#        'Z Khan', 'SB Joshi', 'PA Patel', 'ML Hayden', 'MEK Hussey',
#        'MS Dhoni', 'SK Raina', 'JDP Oram', 'S Badrinath', 'K Goel',
#        'JR Hopes', 'KC Sangakkara', 'Yuvraj Singh', 'SM Katich',
#        'IK Pathan', 'T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif',
#        'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne',
#        'SK Trivedi', 'G Gambhir', 'V Sehwag', 'S Dhawan', 'L Ronchi',
#        'ST Jayasuriya', 'DJ Thornely', 'RV Uthappa', 'PR Shah',
#        'AM Nayar', 'SM Pollock', 'Harbhajan Singh', 'S Chanderpaul',
#        'LRPL Taylor', 'AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxman',
#        'A Symonds', 'RG Sharma', 'SB Styris', 'AS Yadav', 'SB Bangar',
#        'WPUJC Vaas', 'RP Singh', 'WP Saha', 'LR Shukla',
# ...

# %%
data.bowler.unique()
# Out:
# array(['P Kumar', 'Z Khan', 'AA Noffke', 'JH Kallis', 'SB Joshi',
#        'CL White', 'AB Dinda', 'I Sharma', 'AB Agarkar', 'SC Ganguly',
#        'LR Shukla', 'B Lee', 'S Sreesanth', 'JR Hopes', 'IK Pathan',
#        'K Goel', 'PP Chawla', 'WA Mota', 'JDP Oram', 'MS Gony',
#        'M Muralitharan', 'P Amarnath', 'Joginder Sharma', 'GD McGrath',
#        'B Geeves', 'MF Maharoof', 'R Bhatia', 'DL Vettori', 'MM Patel',
#        'SR Watson', 'SK Trivedi', 'SK Warne', 'YK Pathan', 'D Salunkhe',
#        'R Vinay Kumar', 'B Akhil', 'A Nehra', 'SM Pollock', 'DS Kulkarni',
#        'ST Jayasuriya', 'Harbhajan Singh', 'AM Nayar', 'M Kartik',
#        'Mohammad Hafeez', 'DJ Hussey', 'WPUJC Vaas', 'RP Singh',
#        'SB Styris', 'SB Bangar', 'A Symonds', 'PP Ojha', 'Pankaj Singh',
#        'Mohammad Asif', 'VY Mahesh', 'Shahid Afridi', 'DJ Bravo',
#        'VS Yeligati', 'MA Khote', 'D Kalyankrishna', 'VRV Singh',
#        'Sohail Tanvir', 'A Kumble', 'DNT Zoysa', 'SD Chitnis',
# ...

# %%
match['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 143
# Kolkata Knight Riders          122
# Chennai Super Kings            122
# Rajasthan Royals               120
# Royal Challengers Bangalore    113
# Sunrisers Hyderabad             88
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Delhi Capitals                  50
# Deccan Chargers                 43
# Punjab Kings                    24
# Gujarat Titans                  22
# Pune Warriors                   20
# Lucknow Super Giants            19
# Gujarat Lions                   15
# Kochi Tuskers Kerala             8
# Royal Challengers Bengaluru      8
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: count, dtype: int64

# %%
match['toss_winner'].value_counts().plot(kind='pie',figsize=(8,8),autopct='%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %%
match['toss_winner'].value_counts().plot(kind='bar',figsize=(15,4))
# Out:
# <Axes: xlabel='toss_winner'>

# %%
match['toss_decision'].value_counts().head(20).plot(kind='pie',figsize=(15,4),autopct='%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['batter'].value_counts().head(40)
# Out:
# batter
# V Kohli           6236
# S Dhawan          5483
# RG Sharma         5183
# DA Warner         4849
# SK Raina          4177
# MS Dhoni          3947
# RV Uthappa        3927
# AM Rahane         3858
# KD Karthik        3687
# KL Rahul          3578
# G Gambhir         3524
# CH Gayle          3516
# AT Rayudu         3490
# AB de Villiers    3487
# F du Plessis      3435
# MK Pandey         3288
# SV Samson         3270
# SR Watson         2892
# SS Iyer           2545
# SA Yadav          2522
# JC Buttler        2519
# KA Pollard        2447
# PA Patel          2442
# Shubman Gill      2432
# Q de Kock         2410
# RA Jadeja         2378
# WP Saha           2368
# YK Pathan         2334
# RR Pant           2296
# JH Kallis         2291
# BB McCullum       2272
# M Vijay           2208
# Yuvraj Singh      2207
# DA Miller         2171
# MA Agarwal        2081
# SR Tendulkar      2044
# N Rana            2015
# SPD Smith         1999
# Ishan Kishan      1991
# ...

# %%
data['bowler'].value_counts().head(40)
# Out:
# bowler
# R Ashwin           4679
# SP Narine          4146
# B Kumar            4060
# PP Chawla          3895
# RA Jadeja          3895
# YS Chahal          3628
# Harbhajan Singh    3496
# A Mishra           3444
# DJ Bravo           3296
# UT Yadav           3190
# JJ Bumrah          3185
# AR Patel           3152
# SL Malinga         2974
# Sandeep Sharma     2925
# Rashid Khan        2901
# P Kumar            2637
# Mohammed Shami     2521
# I Sharma           2429
# TA Boult           2428
# MM Sharma          2308
# HV Patel           2284
# DW Steyn           2282
# Z Khan             2276
# JD Unadkat         2194
# R Vinay Kumar      2186
# KH Pandya          2183
# SR Watson          2137
# IK Pathan          2113
# Mohammed Siraj     2081
# SN Thakur          1979
# A Nehra            1974
# PP Ojha            1945
# K Rabada           1907
# DS Kulkarni        1876
# RP Singh           1874
# JA Morkel          1807
# CH Morris          1801
# JH Kallis          1799
# ...

# %%
data['batter'].value_counts().head(20).plot(kind='bar',figsize=(10,5))
# Out:
# <Axes: xlabel='batter'>

# %%
data['bowler'].value_counts().head(20).plot(kind='pie',figsize=(10,5),autopct='%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['bowler'].value_counts().head(40).plot(kind='pie',figsize=(10,5),autopct='%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['non_striker'].value_counts().head(20).plot(kind='bar',figsize=(13,5))
# Out:
# <Axes: xlabel='non_striker'>

# %%
data['batsman_runs'].value_counts()
# Out:
# batsman_runs
# 0    103940
# 1     96778
# 4     29850
# 2     16453
# 6     13051
# 3       783
# 5        65
# Name: count, dtype: int64

# %%
data['batsman_runs'].value_counts().plot(kind='pie',figsize=(10,5),autopct='%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data[data['over']==1]
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 7         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 8         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 9         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 10        335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 11        335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260862   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260863   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260864   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260865   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260866   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
over=data[(data['match_id']==1)]['over']
run=data[(data['match_id']==1) & (data['over']==1)]['total_runs'].sum()
run
# Out:
# 0

# %%
(data['over'].value_counts()/6).plot(kind='bar', figsize=(15,5))
# Out:
# <Axes: xlabel='over'>

# %%
data['total_runs'].value_counts()
# Out:
# total_runs
# 1    108440
# 0     90438
# 4     30221
# 2     17323
# 6     12964
# 3       922
# 5       524
# 7        88
# Name: count, dtype: int64

# %%
data['total_runs'].value_counts().plot(kind='bar',figsize=(13,5))
# Out:
# <Axes: xlabel='total_runs'>

# %%
match['player_of_match'].value_counts()
# Out:
# player_of_match
# AB de Villiers       25
# CH Gayle             22
# RG Sharma            19
# DA Warner            18
# V Kohli              18
#                      ..
# NV Ojha               1
# KV Sharma             1
# Washington Sundar     1
# PD Collingwood        1
# Shahbaz Ahmed         1
# Name: count, Length: 291, dtype: int64

# %%
match['player_of_match'].value_counts().head(15).plot(kind='pie',figsize=(8,8),autopct='%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %%
match['result'].value_counts().head(15).plot(kind='bar',figsize=(15,5))
# Out:
# <Axes: xlabel='result'>

# %% [markdown]
# ### TO find the winner and plot in the formet of bar

# %%
match['winner'].value_counts().plot(kind='bar',figsize=(15,4,))
# Out:
# <Axes: xlabel='winner'>

# %%
match['target_runs'].value_counts().head(20).plot(kind='bar',figsize=(15,4))
# Out:
# <Axes: xlabel='target_runs'>

# %%
data[data.batter=='MS Dhoni']
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 265       335983       1  Chennai Super Kings              Kings XI Punjab
# 268       335983       1  Chennai Super Kings              Kings XI Punjab
# 269       335983       1  Chennai Super Kings              Kings XI Punjab
# 1719      335989       1  Chennai Super Kings               Mumbai Indians
# 1720      335989       1  Chennai Super Kings               Mumbai Indians
# ...          ...     ...                  ...                          ...
# 259777   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
# 259780   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
# 259781   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
# 259783   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
# 259784   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
#
# ...

# %%
data[data.batter=='MS Dhoni'].batsman_runs
# Out:
# 265       1
# 268       1
# 269       0
# 1719      0
# 1720      4
#          ..
# 259777    1
# 259780    4
# 259781    1
# 259783    6
# 259784    0
# Name: batsman_runs, Length: 3947, dtype: int64

# %% [markdown]
# ### To find the total runs of batsman

# %%
data[data.batter=='MS Dhoni'].batsman_runs.sum()
# Out:
# 5243

# %%
balls_faced=len(data[data.batter=='MS Dhoni'].batsman_runs)
runs=data[data.batter=='MS Dhoni'].batsman_runs.sum()

# %%
(runs/balls_faced)*100
# Out:
# 132.8350646060299

# %%
balls_faced=len(data[data.batter=='MS Dhoni'].batsman_runs)
runs=data[data.batter=='MS Dhoni'].batsman_runs.sum()
strike_rate=((runs/balls_faced)*100)

# %%
player=input("Enter player name")
balls_faced=len(data[data.batter==player].batsman_runs)
runs=data[data.batter==player].batsman_runs.sum()
strike_rate=((runs/balls_faced)*100)
print(player,"has scored",runs,"runs")
print(player,"has a strike rate of",strike_rate)
# Out:
# Enter player nameBB McCullum
# BB McCullum has scored 2882 runs
# BB McCullum has a strike rate of 126.84859154929578

# %% [markdown]
# #### calculation to find the strike rate of player

# %%
player=input("Enter player name")
balls_faced=len(data[data.batter==player].batsman_runs)
runs=data[data.batter==player].batsman_runs.sum()
strike_rate=((runs/balls_faced)*100)
print(player,"has scored",runs,"runs")
print(player,"has a strike rate of",strike_rate)
